# %%
from python_scripts.web_scraping import reviews,ratings
ratings = ratings[:-7]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(reviews, ratings, test_size=0.33, random_state=42)

# %%
for i in range(len(X_train)):
    X_train[i] = X_train[i].lower().split()

# %%
from nltk.stem import WordNetLemmatizer
for i in X_train:
    X_train[X_train.index(i)]=[WordNetLemmatizer().lemmatize(t) for t in i]
X_train
# Out:
# [['worth',
#   'not',
#   'even',
#   'writing',
#   'a',
#   'review.',
#   'just',
#   'bad',
#   'timing',
#   'of',
#   'jokes,',
#   'bad',
#   'performances.'],
#  ['this',
#   'film',
#   'could',
#   'have',
#   'been',
#   'brilliant',
#   'but',
#   'it',
#   'been',
#   'made',
#   'into',
#   'a',
#   'shameless',
#   'joke.',
#   'a',
#   'very',
#   'important',
#   'question',
#   'of',
#   "'what",
#   'would',
#   'you',
#   "do?'",
#   'ha',
#   'been',
#   'made',
#   'into',
#   'a',
#   'laughing',
#   'stock',
#   'karan',
#   'johar',
#   'level',
#   'bollywood',
#   'crap.',
#   'the',
#   'first',
#   'half',
#   'is',
#   'unbearable',
#   'while',
#   'the',
#   'second',
#   'half',
#   'is',
#   "'bearable'.the",
#   'story',
#   'is',
#   'simply',
#   'pulled',
#   'a',
#   'much',
#   'a',
#   'they',
#   'could',
#   'to',
#   'make',
#   'a',
#   'short',
#   'film',
#   'into',
#   'a',
#   'feature',
#   'length',
#   'film',
#   'only',
# ...
